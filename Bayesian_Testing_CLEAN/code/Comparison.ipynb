# %% [markdown]
# # Homework 2
# ## A/B Testing with Epsilon-Greedy and Thompson Sampling
#
# This notebook imports the implementation from `Bandit.py`, runs both algorithms, and presents the required outputs.

# %%
from Bandit import comparison
import numpy as np

# %%
epsilon_greedy_model, thompson_sampling_model, combined_results = comparison()

print(f"Epsilon-Greedy cumulative reward: {np.sum(epsilon_greedy_model.rewards):.4f}")
print(f"Epsilon-Greedy cumulative regret: {np.sum(epsilon_greedy_model.regrets):.4f}")
print(f"Thompson Sampling cumulative reward: {np.sum(thompson_sampling_model.rewards):.4f}")
print(f"Thompson Sampling cumulative regret: {np.sum(thompson_sampling_model.regrets):.4f}")
# Out:
# 2026-04-13 13:41:22.343 | INFO     | Bandit:experiment:194 - EpsilonGreedy experiment completed.
# 2026-04-13 13:41:22.754 | INFO     | Bandit:experiment:294 - ThompsonSampling experiment completed.
# 2026-04-13 13:41:22.809 | INFO     | Bandit:report:209 - EpsilonGreedy cumulative reward: 79734.4694
# 2026-04-13 13:41:22.809 | INFO     | Bandit:report:210 - EpsilonGreedy cumulative regret: 135.0000
# 2026-04-13 13:41:22.866 | INFO     | Bandit:report:309 - ThompsonSampling cumulative reward: 79369.1285
# 2026-04-13 13:41:22.867 | INFO     | Bandit:report:310 - ThompsonSampling cumulative regret: 598.0000
# 2026-04-13 13:41:24.352 | INFO     | Bandit:comparison:336 - Comparison of Epsilon-Greedy and Thompson Sampling completed.
# Epsilon-Greedy cumulative reward: 79734.4694
# Epsilon-Greedy cumulative regret: 135.0000
# Thompson Sampling cumulative reward: 79369.1285
# Thompson Sampling cumulative regret: 598.0000
